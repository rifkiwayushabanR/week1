# %%
tA = (90, 90, 90, 90)

hasil = all(x == tA[0] for x in tA)

print(hasil)
# Out:
# True

# %%
data = ('Rifki Wahyu Shaban Rizaldi', '71251225', 'Lampung')

print("Data:", data)

print("NIM :", data[1])
print("NAMA :", data[0])
print("ALAMAT :", data[2])

nim_tuple = tuple(data[1])
print("NIM:", nim_tuple)

nama_depan = tuple(data[0].split()[0])
print("NAMA DEPAN:", nama_depan)

nama_terbalik = tuple(data[0].split()[::-1])
print("NAMA TERBALIK:", nama_terbalik)
# Out:
# Data: ('Rifki Wahyu Shaban Rizaldi', '71251225', 'Lampung')
# NIM : 71251225
# NAMA : Rifki Wahyu Shaban Rizaldi
# ALAMAT : Lampung
# NIM: ('7', '1', '2', '5', '1', '2', '2', '5')
# NAMA DEPAN: ('R', 'i', 'f', 'k', 'i')
# NAMA TERBALIK: ('Rizaldi', 'Shaban', 'Wahyu', 'Rifki')
