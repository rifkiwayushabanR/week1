# %%
def perkalian(a, b):
    c = []
    e = 1
    while e < a:
        c.append(str(b))
        c.append("+")
        e += 1
    c.append(str(b))
    c.append("=")
    d = " ".join(c)
    return d

bil1 = int(input("Silahkan masukan bilangan pertama anda\n>> "))
bil2 = int(input("Silahkan masukan bilangan kedua anda\n>> "))

c = perkalian(bil1, bil2)
print(f"{c} {bil1 * bil2}")
# Out:
# Silahkan masukan bilangan pertama anda
# >>  5
# Silahkan masukan bilangan kedua anda
# >>  6
# 6 + 6 + 6 + 6 + 6 = 30
