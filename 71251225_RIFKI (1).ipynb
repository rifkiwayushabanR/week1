# %%
import re
from datetime import datetime

teks = """Pada tanggal 1945-08-17 Indonesia merdeka. Indonesia memiliki beberapa pahlawan
nasional, seperti Pangeran Diponegoro (TL: 1785-11-11), Pattimura (TL: 1783-06-08) dan Ki
Hajar Dewantara (1889-05-02)."""

# cari semua tanggal dengan regex
tanggal_list = re.findall(r'\d{4}-\d{2}-\d{2}', teks)

sekarang = datetime.now()

for tgl in tanggal_list:
    # ubah string ke datetime
    tgl_obj = datetime.strptime(tgl, "%Y-%m-%d")
    
    # ubah format ke DD-MM-YYYY
    format_baru = tgl_obj.strftime("%d-%m-%Y")
    
    # hitung selisih hari
    selisih = (sekarang - tgl_obj).days
    
    print(f"{tgl_obj} selisih {selisih} hari")
# Out:
# 1945-08-17 00:00:00 selisih 29464 hari
# 1785-11-11 00:00:00 selisih 87816 hari
# 1783-06-08 00:00:00 selisih 88703 hari
# 1889-05-02 00:00:00 selisih 50024 hari

# %%
import re
import random
import string

teks = """Berikut adalah daftar email dan nama pengguna dari mailing list:
anton@mail.com dimiliki oleh antonius
budi@gmail.co.id dimiliki oleh budi anwari
slamet@getnada.com dimiliki oleh slamet slumut
matahari@tokopedia.com dimiliki oleh toko matahari"""

# cari semua email
emails = re.findall(r'[\w\.-]+@[\w\.-]+', teks)

for email in emails:
    # ambil username (sebelum @)
    username = email.split('@')[0]
    
    # generate password random (huruf + angka)
    password = ''.join(random.choices(string.ascii_letters + string.digits, k=8))
    
    print(f"{email} username: {username} , password: {password}")
# Out:
# anton@mail.com username: anton , password: 15TgHyAE
# budi@gmail.co.id username: budi , password: rUASlTt8
# slamet@getnada.com username: slamet , password: HZDhotVK
# matahari@tokopedia.com username: matahari , password: wRfdmX82
